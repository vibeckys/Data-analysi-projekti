# %%
import pandas as pd  #Pandasia käytetään datan käsittelyyn ja esikäsittelyyn.
import numpy as np   #NumPyn avulla suoritetaan matemaattisia operaatioita.

# %% [markdown]
# Se valmistaa työkalut datan käsittelyyn ja laskentaan.

# %%
df = pd.read_csv("hulu_titles.csv") # Meidän dataseti.

# %% [markdown]
# lukee CSV-tiedoston nimeltä hulu_titles.csv ja tallentaa sen sisällön DataFrame-muotoon muuttujaan df

# %%
# Tämä näyttää DataFrame:n ensimmäiset 10 riviä.
df.head(10)
# Out:
#   show_id     type                           title director  cast  \
# 0      s1    Movie  Ricky Velez: Here's Everything      NaN   NaN
# 1      s2    Movie                    Silent Night      NaN   NaN
# 2      s3    Movie                    The Marksman      NaN   NaN
# 3      s4    Movie                            Gaia      NaN   NaN
# 4      s5    Movie                        Settlers      NaN   NaN
# 5      s6  TV Show   The Halloween Candy Magic Pet      NaN   NaN
# 6      s7    Movie              The Evil Next Door      NaN   NaN
# 7      s8  TV Show          The Next Thing You Eat      NaN   NaN
# 8      s9  TV Show                          Queens      NaN   NaN
# 9     s10  TV Show                The Bachelorette      NaN   NaN
#
#          country        date_added  release_year rating   duration  \
# 0            NaN  October 24, 2021          2021  TV-MA        NaN
# 1            NaN  October 23, 2021          2020    NaN     94 min
# ...

# %%
# Esitä sarakkeiden otsikot.
name_columns = len(df.columns)
print (f"The names of columns is: {df.columns}")
# Out:
# The names of columns is: Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
#     Tämä näyttä meidän DataFramen sarakkeiden nimet, eli esitä sarakkeiden otsikot.

# %%
#Esikätselu rivien ja sarakkeiden kokonaismäärä
rows, columns = df.shape
print(f"Our dataset contains {rows} rows and {columns} columns.")
# Out:
# Our dataset contains 3073 rows and 12 columns.

# %% [markdown]
# df.shape palauttaa tuple-tyyppisen arvon: (rivien_lkm, sarakkeiden_lkm).

# %%
#Viewing a random sample of our data.
random_sample=df.sample(10)
print(random_sample)
# Out:
#      show_id     type                                    title director  cast  \
# 630     s631  TV Show    Sarah Beeny's Renovate Don't Relocate      NaN   NaN
# 66       s67    Movie                          Pacific Airshow      NaN   NaN
# 1496   s1497    Movie                        Raging Bull Shark      NaN   NaN
# 2277   s2278  TV Show                     The Bob Newhart Show      NaN   NaN
# 1397   s1398    Movie                                The Fight      NaN   NaN
# 1277   s1278  TV Show  Basic Versus Baller: Travel at Any Cost      NaN   NaN
# 1878   s1879  TV Show        Gold Rush: Dave Turin's Lost Mine      NaN   NaN
# 1679   s1680  TV Show                           Street Outlaws      NaN   NaN
# 1485   s1486    Movie                               In My Skin      NaN   NaN
# 21       s22  TV Show                                 Hoarders      NaN   NaN
#
#              country          date_added  release_year    rating   duration  \
# ...

# %% [markdown]
# ** meidän on säädettävä numeroa 10 saadakseen suuremman tai pienemmän näytteen riippuen siitä, mitä haluamme analysoida.**

# %%
column_data_types = df.dtypes
print(column_data_types)
# Out:
# show_id          object
# type             object
# title            object
# director         object
# cast            float64
# country          object
# date_added       object
# release_year      int64
# rating           object
# duration         object
# listed_in        object
# description      object
# dtype: object

# %% [markdown]
# Hae useiden sarakkeiden datatyypit esimmerkki  release_year datatyypi is int64.

# %%
#Jos halutaan katoo tarkaan saraken data tyypi.
column_data_type = df['cast'].dtype
print(column_data_type)
# Out:
# float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3073 entries, 0 to 3072
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       3073 non-null   object
#  1   type          3073 non-null   object
#  2   title         3073 non-null   object
#  3   director      3 non-null      object
#  4   cast          0 non-null      float64
#  5   country       1620 non-null   object
#  6   date_added    3045 non-null   object
#  7   release_year  3073 non-null   int64
#  8   rating        2553 non-null   object
#  9   duration      2594 non-null   object
#  10  listed_in     3073 non-null   object
#  11  description   3069 non-null   object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 288.2+ KB

# %% [markdown]
# Tämä näyttää yhteenvedon tiedoista DataFrame:sta.Se antaa hyödyllistä tietoa, kuten datatyypit ja puuttuvien arvojen määrän.

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# Tulostaa kaikkien sarakkeiden nimet.

# %% [markdown]
# ===========================  Missing values ==================================

# %%
# Metodilla isnull() voidaan kato puutuvien arvo ja jos lasketaan summa nii voidaan laskea puutuvien arvojen määrä.
missing_count = df.isnull().sum()
print(missing_count)
# Out:
# show_id            0
# type               0
# title              0
# director        3070
# cast            3073
# country         1453
# date_added        28
# release_year       0
# rating           520
# duration         479
# listed_in          0
# description        4
# dtype: int64

# %% [markdown]
# Tässä näky että dataset puutuu arvo, eli director, cast, country, date_added, rating, duration ja description sarakeesta puutuu arvo.

# %%
#Percentage of the missing data per column.
missing_count = df.isnull().sum()  #Check for missing values
total_rows = len(df)   #Total rows in the dataset
missing_percentage = (missing_count / total_rows) * 100 # Calculate the percentage of missing data for each column
# Check if there are any missing values
if missing_count.sum() > 0:
    print("The dataset contains missing values.")
    print("\nMissing data summary (in percentages):")
    print(missing_percentage)
else:
    print("The dataset does not contain any missing values.")
# Out:
# The dataset contains missing values.
#
# Missing data summary (in percentages):
# show_id           0.000000
# type              0.000000
# title             0.000000
# director         99.902376
# cast            100.000000
# country          47.282786
# date_added        0.911162
# release_year      0.000000
# rating           16.921575
# duration         15.587374
# listed_in         0.000000
# description       0.130166
# dtype: float64

# %% [markdown]
# Tässä tapauksessa puuttuvien arvojen osuus on ilmaistu prosentteina kullekin sarakkeelle joissa on paljon puuttuvia arvoja esim. director ja cast.

# %%
import pandas as pd
import numpy as np
#Tarkistetaan porsentualista osutta tyhjista arvosta
total_data=np.prod(df.shape)  #Tarkastele paljonko sitä data on.
# Calculate the total number of missing values
total_missing = df.isnull().sum().sum()

# Calculate the percentage of missing data
per_of_missing_data = (total_missing / total_data) * 100

# Print the percentage of missing data
print(f"Percentage of missing data: {per_of_missing_data:.2f}%")
# Out:
# Percentage of missing data: 33.33%

# %% [markdown]
# =======================  Puutuvien arvon käsittely =====================

# %%
#Replace all NaN elements with 0s
df.fillna(0)
# Out:
#      show_id     type                           title director  cast  \
# 0         s1    Movie  Ricky Velez: Here's Everything        0   0.0
# 1         s2    Movie                    Silent Night        0   0.0
# 2         s3    Movie                    The Marksman        0   0.0
# 3         s4    Movie                            Gaia        0   0.0
# 4         s5    Movie                        Settlers        0   0.0
# ...      ...      ...                             ...      ...   ...
# 3068   s3069  TV Show  Star Trek: The Original Series        0   0.0
# 3069   s3070  TV Show              Star Trek: Voyager        0   0.0
# 3070   s3071  TV Show                       The Fades        0   0.0
# 3071   s3072  TV Show               The Twilight Zone        0   0.0
# 3072   s3073  TV Show             Tokyo Magnitude 8.0        0   0.0
#
#              country        date_added  release_year rating   duration  \
# 0                  0  October 24, 2021          2021  TV-MA
# ...

# %%
df.dropna(axis=1, how='any')
#Pudota sarakkeet, joissa jokin elementeistä on nan
# Out:
#      show_id     type                           title  release_year  \
# 0         s1    Movie  Ricky Velez: Here's Everything          2021
# 1         s2    Movie                    Silent Night          2020
# 2         s3    Movie                    The Marksman          2021
# 3         s4    Movie                            Gaia          2021
# 4         s5    Movie                        Settlers          2021
# ...      ...      ...                             ...           ...
# 3068   s3069  TV Show  Star Trek: The Original Series          1966
# 3069   s3070  TV Show              Star Trek: Voyager          1997
# 3070   s3071  TV Show                       The Fades          2011
# 3071   s3072  TV Show               The Twilight Zone          1959
# 3072   s3073  TV Show             Tokyo Magnitude 8.0          2009
#
#        duration                               listed_in
# 0                                      Comedy, Stand Up
# ...

# %%
#Tunnistaa päällekkäiset rivit DataFramesta. Se palauttaa Boolen sarjan
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3068    False
# 3069    False
# 3070    False
# 3071    False
# 3072    False
# Length: 3073, dtype: bool

# %%
duplicate_rows = df.duplicated()

num_duplicates = duplicate_rows.sum()
print(f"Number of duplicate rows: {num_duplicates}")
# Out:
# Number of duplicate rows: 0

# %% [markdown]
# Rivien kaksoiskappaleita ei ole.

# %%
#Separate one of your columns in the dataset that contains continuous numeric data into appropriate bins. You may use cut or qcut function.
column_data_type = df['release_year'].dtype
print(column_data_type)
# Example binning  cut
release_years = [2021,2020,2021,2021,2021,1966,1997,2011,1959,2009]
bins = [1959,1997,2009,2011,2020,2021]
gnames = ['Second least releases', 'second most releases', 'least releases','Most releases','third most releases']
release_years_bins = pd.cut(df['release_year'], bins, labels=gnames)
# to check the categories
#lets count the values for each bin
pd.value_counts(release_years_bins)
# Out:
# int64
# C:\Users\vibec\AppData\Local\Temp\ipykernel_41448\3331858479.py:11: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(release_years_bins)
# release_year
# Most releases            1990
# second most releases      462
# third most releases       226
# Second least releases     214
# least releases            159
# Name: count, dtype: int64

# %% [markdown]
# Alla on koodi miten saadaan katsottua outliers. Ja lisättyä outliers kun niitä ei ollut. Eli siis ne kaksi kohtaa jotka pyysit tekemään.

# %%
import numpy as np
import pandas as pd

def identify_outliers(dataframe, column, threshold=3):
    df = dataframe.copy()
    mean = df[column].mean()
    std = df[column].std()
    df["Z-Score"] = (df[column] - mean) / std
    outliers = df[np.abs(df["Z-Score"]) > threshold]
    return outliers

def add_random_outliers(dataframe, column, num_outliers=5, range_multiplier=3, threshold=3):
    df = dataframe.copy()
    mean = df[column].mean()
    std = df[column].std()
    for _ in range(num_outliers):
        outlier_value = mean + threshold * std * np.random.choice([-1.5, 1.5])
        random_index = np.random.randint(0, len(df))
        df.loc[random_index, column] = outlier_value
    return df

data = {"Value": np.random.normal(loc=50, scale=5, size=100)}
df = pd.DataFrame(data)

outliers = identify_outliers(df, column="Value")

if outliers.empty:
    df = add_random_outliers(df, column="Value", num_outliers=5, threshold=3)
    outliers = identify_outliers(df, column="Value")

print(outliers)
# Out:
#         Value   Z-Score
# 2   31.113845 -3.215708
# 8   69.899477  3.174791
# 33  69.899477  3.174791
# 76  31.113845 -3.215708
# 91  69.899477  3.174791

# %% [markdown]
# ============================== Data Objects & Attribute Types  ============================

# %%
print("These are the nominal attributes: ")
print(["show id", "type", "title", "release_year", "listed_in", "rating"])
#binary attributes
print("There are no binary attributes here in our dataset.")
#ordinal attributes
print("The ordinal attribute in out dataset is: ")
print(df['release_year'].value_counts())
print("Release year is an ordinal attribute since it can be put in an order among it's own group")
# Out:
# These are the nominal attributes:
# ['show id', 'type', 'title', 'release_year', 'listed_in', 'rating']
# There are no binary attributes here in our dataset.
# The ordinal attribute in out dataset is:
# release_year
# 2019    412
# 2020    377
# 2018    270
# 2017    229
# 2021    226
#        ...
# 1933      1
# 1923      1
# 1968      1
# 1961      1
# 1954      1
# Name: count, Length: 72, dtype: int64
# Release year is an ordinal attribute since it can be put in an order among it's own group

# %% [markdown]
# ===============================  Basic Statistics ================================

# %% [markdown]
# Tässä on keskiarvo, mediaani, poikkeama ja varianssi laskettuna

# %%
#calculate the mean, median, standard deviation, and variance of the release_year column.
average_release_year = np.mean(df['release_year'])
print('the average release year is:', average_release_year)
median_release_year = np.median(df['release_year'])
print('the median release year is:', median_release_year)
std_release_year = np.std(df['release_year'])
print('the standard deviation of release year is:', std_release_year)
var_release_year = np.var(df['release_year'])
print('the variance of release year is:', var_release_year)
# Out:
# the average release year is: 2012.5675235925805
# the median release year is: 2016.0
# the standard deviation of release year is: 10.842304227790304
# the variance of release year is: 117.5555609679595

# %% [markdown]
# Tässä on minimi- ja maksimi laskuja julkaisuvuosista.

# %%
#getting the minimmum and maximum release year + the sum of the release year
sum_release_year = np.sum(df['release_year'])
print('the total sum of  release year is:', sum_release_year)
max_release_year = np.max(df['release_year'])
print('the maximum release year is:', max_release_year)
min_release_year = np.min(df['release_year'])
print('the minimum release year is:', min_release_year)
# Out:
# the total sum of  release year is: 6184620
# the maximum release year is: 2021
# the minimum release year is: 1923

# %% [markdown]
# ===============================  Visualization ===================================

# %% [markdown]
# Tämä koodi näyttää meillä, kuinka monta elokuvaa vuodessa ollaan julkaistu. Barchart, pylväskaavio.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# file_path = "c:\Users\vibec\OneDrive\Escritorio\Phyton - Data analysis\hulu_titles.csv"
# df = pd.read_csv(file_path)

print("Dataset Preview:")

print(df.head())
print(df.columns)

df['release_year'].value_counts().sort_index().plot(kind='bar', color='orange', figsize=(12, 6))
plt.title('Number of Movies by Release Year')
plt.xlabel('Year')
plt.ylabel('Count')
plt.show()
# Out:
# Dataset Preview:
#   show_id   type                           title director  cast country  \
# 0      s1  Movie  Ricky Velez: Here's Everything      NaN   NaN     NaN
# 1      s2  Movie                    Silent Night      NaN   NaN     NaN
# 2      s3  Movie                    The Marksman      NaN   NaN     NaN
# 3      s4  Movie                            Gaia      NaN   NaN     NaN
# 4      s5  Movie                        Settlers      NaN   NaN     NaN
#
#          date_added  release_year rating duration                  listed_in  \
# 0  October 24, 2021          2021  TV-MA      NaN           Comedy, Stand Up
# 1  October 23, 2021          2020    NaN   94 min     Crime, Drama, Thriller
# 2  October 23, 2021          2021  PG-13  108 min           Action, Thriller
# 3  October 22, 2021          2021      R   97 min                     Horror
# 4  October 22, 2021          2021    NaN  104 min  Science Fiction, Thriller
#
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
fip = plt.figure()
ax = plt.axes ()

x = df ['release_year']
y = df ['duration']
plt.plot(x, y)
plt.title('julkaisvuodet ja kesto')
plt.show()

# %% [markdown]
# Tämä koodi näyttää histogrammina kuinka kauan elokuvat kestävät.

# %%
import pandas as pd
import matplotlib.pyplot as plt


df['duration'] = df['duration'].str.extract('(\d+)').astype(float)
print(df['duration'].isnull().sum()) 

df['duration'].dropna().plot(kind='hist', bins=20, color='lightblue', edgecolor='black', figsize=(10, 6))
plt.title('Distribution of Movie Durations')
plt.xlabel('Duration (minutes)')
plt.ylabel('Frequency')
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\d'
# <>:5: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\vibec\AppData\Local\Temp\ipykernel_41448\337214555.py:5: SyntaxWarning: invalid escape sequence '\d'
#   df['duration'] = df['duration'].str.extract('(\d+)').astype(float)
# 479

# %% [markdown]
# Tämä ympyrä diakrammi esittää minkälaisia ikäsuosituksia elokuvilla on. Piechart

# %%
import pandas as pd
import matplotlib.pyplot as plt


rating_counts = df['rating'].value_counts()


valid_ratings = ['G', 'PG', 'PG-13', 'R', 'TV-MA']

df_cleaned = df[df['rating'].isin(valid_ratings)]

cleaned_rating_counts = df_cleaned['rating'].value_counts()

plt.figure(figsize=(8, 8))
plt.pie(cleaned_rating_counts, labels=cleaned_rating_counts.index, autopct='%1.1f%%', colors=['lightgreen', 'lightblue', 'lightcoral', 'gold', 'lightpink'], startangle=90, wedgeprops={'edgecolor': 'black'})

plt.title('Distribution of Valid Movie Ratings', fontsize=16)


plt.show()

# %% [markdown]
# tässä on elokuvat julkaisuvuosien mukaan

# %%
df['release_year'].value_counts().sort_index().plot(kind='bar', color='orange', figsize=(12, 6))
plt.title('Number of Movies by Release Year')
plt.xlabel('Year')
plt.ylabel('Count')
plt.show()

# %%
df.head(10)
# Out:
#   show_id     type                           title director  cast  \
# 0      s1    Movie  Ricky Velez: Here's Everything      NaN   NaN
# 1      s2    Movie                    Silent Night      NaN   NaN
# 2      s3    Movie                    The Marksman      NaN   NaN
# 3      s4    Movie                            Gaia      NaN   NaN
# 4      s5    Movie                        Settlers      NaN   NaN
# 5      s6  TV Show   The Halloween Candy Magic Pet      NaN   NaN
# 6      s7    Movie              The Evil Next Door      NaN   NaN
# 7      s8  TV Show          The Next Thing You Eat      NaN   NaN
# 8      s9  TV Show                          Queens      NaN   NaN
# 9     s10  TV Show                The Bachelorette      NaN   NaN
#
#          country        date_added  release_year rating   duration  \
# 0            NaN  October 24, 2021          2021  TV-MA        NaN
# 1            NaN  October 23, 2021          2020    NaN     94 min
# ...

# %%
print(df['duration'].dtype)
print(df['duration'].head())
values = {'duration': ''}
df = df.fillna(value=values)
missing_count = df.isnull().sum()
print(missing_count)
df.shape
# Out:
# object
# 0        NaN
# 1     94 min
# 2    108 min
# 3     97 min
# 4    104 min
# Name: duration, dtype: object
# show_id            0
# type               0
# title              0
# director        3070
# cast            3073
# country         1453
# date_added        28
# release_year       0
# rating           520
# duration           0
# listed_in          0
# description        4
# dtype: int64
# (3073, 12)

# %%
import matplotlib.pyplot as plt
x1 = df['release_year']
y1 = df['duration']
plt.scatter(x1, y1)
plt.title('scatter plot esimekki')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
from mpl_toolkits.mplot3d import axes3d

df = pd.read_csv('hulu_titles.csv')

x = df['release_year']  
y = df['rating'] 
z = df['duration'] 

x = pd.to_numeric(x, errors='coerce').dropna()
y = pd.to_numeric(y, errors='coerce').dropna()
z = pd.to_numeric(z, errors='coerce').dropna()

fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')

ax.scatter(x, y, z, c='b', marker='o', label='blue')


ax.set_xlabel('Year')
ax.set_ylabel('Rating')
ax.set_zlabel('Duration')
plt.title("3D Scatter Plot for Hulu Titles")

plt.legend()

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 18
#      15 fig = plt.figure()
#      16 ax = fig.add_subplot(111, projection = '3d')
# ---> 18 ax.scatter(x, y, z, c='b', marker='o', label='blue')
#      21 ax.set_xlabel('Year')
#      22 ax.set_ylabel('Rating')
#
# File c:\Python313\Lib\site-packages\matplotlib\__init__.py:1476, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1473 @functools.wraps(func)
#    1474 def inner(ax, *args, data=None, **kwargs):
#    1475     if data is None:
# -> 1476         return func(
#    1477             ax,
#    1478             *map(sanitize_sequence, args),
#    1479             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1481     bound = new_sig.bind(ax, *args, **kwargs)
#    1482     auto_label = (bound.arguments.get(label_namer)
# ...
